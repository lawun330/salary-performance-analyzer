# %% [markdown]
# # Minimum Wage Extractor: Version 1.0
#
# The salary–performance optimizer requires a lower bound to ensure that salary recommendations never fall below a realistic, legally compliant minimum.
#
# The [**OECD**](https://data-explorer.oecd.org) publishes comparable, official minimum wage statistics across countries, making it a reliable external source. The data is reported in USD.
#
# Using this data, employees can verify that employers are not exploiting them by offering pay below a realistic, legal minimum.

# %%
import requests
import pandas as pd
from io import StringIO

# %%
# define API query URL (CSV with labels format)
url = "https://sdmx.oecd.org/public/rest/data/OECD.ELS.SAE,DSD_EARNINGS@MW_CURP,1.0/..USD.A...?startPeriod=2010&dimensionAtObservation=AllDimensions&format=csvfilewithlabels"

# fetch data
response = requests.get(url)

# %%
# load into DataFrame
df = pd.read_csv(StringIO(response.text))
df.head()
# Out:
#   STRUCTURE                            STRUCTURE_ID  \
# 0  DATAFLOW  OECD.ELS.SAE:DSD_EARNINGS@MW_CURP(1.0)
# 1  DATAFLOW  OECD.ELS.SAE:DSD_EARNINGS@MW_CURP(1.0)
# 2  DATAFLOW  OECD.ELS.SAE:DSD_EARNINGS@MW_CURP(1.0)
# 3  DATAFLOW  OECD.ELS.SAE:DSD_EARNINGS@MW_CURP(1.0)
# 4  DATAFLOW  OECD.ELS.SAE:DSD_EARNINGS@MW_CURP(1.0)
#
#                                       STRUCTURE_NAME ACTION REF_AREA  \
# 0  Minimum wages at current prices in national cu...      I      USA
# 1  Minimum wages at current prices in national cu...      I      USA
# 2  Minimum wages at current prices in national cu...      I      USA
# 3  Minimum wages at current prices in national cu...      I      USA
# 4  Minimum wages at current prices in national cu...      I      USA
#
#   Reference area MEASURE                  Measure UNIT_MEASURE  \
# 0  United States   SM_WG  Statutory minimum wages          USD
# 1  United States   SM_WG  Statutory minimum wages          USD
# 2  United States   SM_WG  Statutory minimum wages          USD
# 3  United States   SM_WG  Statutory minimum wages          USD
# 4  United States   SM_WG  Statutory minimum wages          USD
#
#   Unit of measure  ... OBS_VALUE Observation value BASE_PER Base period  \
# 0       US dollar  ...     15080               NaN      NaN         NaN
# 1       US dollar  ...     15080               NaN      NaN         NaN
# 2       US dollar  ...     15080               NaN      NaN         NaN
# 3       US dollar  ...     15080               NaN      NaN         NaN
# 4       US dollar  ...     15080               NaN      NaN         NaN
#
#   OBS_STATUS Observation status UNIT_MULT Unit multiplier  DECIMALS  Decimals
# 0          A       Normal value         0           Units         1       One
# 1          A       Normal value         0           Units         1       One
# 2          A       Normal value         0           Units         1       One
# 3          A       Normal value         0           Units         1       One
# 4          A       Normal value         0           Units         1       One
#
# [5 rows x 30 columns]

# %%
df.columns
# Out:
# Index(['STRUCTURE', 'STRUCTURE_ID', 'STRUCTURE_NAME', 'ACTION', 'REF_AREA',
#        'Reference area', 'MEASURE', 'Measure', 'UNIT_MEASURE',
#        'Unit of measure', 'PAY_PERIOD', 'Pay period', 'PRICE_BASE',
#        'Price base', 'AGGREGATION_OPERATION', 'Aggregation operation', 'SEX',
#        'Sex', 'TIME_PERIOD', 'Time period', 'OBS_VALUE', 'Observation value',
#        'BASE_PER', 'Base period', 'OBS_STATUS', 'Observation status',
#        'UNIT_MULT', 'Unit multiplier', 'DECIMALS', 'Decimals'],
#       dtype='object')

# %%
cols_to_drop = ['STRUCTURE', 'STRUCTURE_ID', 'STRUCTURE_NAME', 'ACTION', 
                'Reference area', 'MEASURE',
                'Unit of measure', 'PAY_PERIOD', 'PRICE_BASE',
                'AGGREGATION_OPERATION', 'Aggregation operation', 'SEX',
                'Sex', 'Time period', 'Observation value',
                'BASE_PER', 'Base period', 'OBS_STATUS', 'Observation status',
                'UNIT_MULT', 'Unit multiplier', 'DECIMALS', 'Decimals']

# %%
df.drop(cols_to_drop, axis=1, inplace=True)

# %%
df = df.set_index('TIME_PERIOD')

# %%
df
# Out:
#             REF_AREA                  Measure UNIT_MEASURE Pay period  \
# TIME_PERIOD
# 2010             USA  Statutory minimum wages          USD     Annual
# 2011             USA  Statutory minimum wages          USD     Annual
# 2012             USA  Statutory minimum wages          USD     Annual
# 2013             USA  Statutory minimum wages          USD     Annual
# 2014             USA  Statutory minimum wages          USD     Annual
# 2015             USA  Statutory minimum wages          USD     Annual
# 2016             USA  Statutory minimum wages          USD     Annual
# 2017             USA  Statutory minimum wages          USD     Annual
# 2018             USA  Statutory minimum wages          USD     Annual
# 2019             USA  Statutory minimum wages          USD     Annual
# 2020             USA  Statutory minimum wages          USD     Annual
# 2021             USA  Statutory minimum wages          USD     Annual
# 2022             USA  Statutory minimum wages          USD     Annual
# 2023             USA  Statutory minimum wages          USD     Annual
# 2024             USA  Statutory minimum wages          USD     Annual
# 2025             USA  Statutory minimum wages          USD     Annual
#
#                  Price base  OBS_VALUE
# TIME_PERIOD
# 2010         Current prices      15080
# 2011         Current prices      15080
# 2012         Current prices      15080
# 2013         Current prices      15080
# 2014         Current prices      15080
# 2015         Current prices      15080
# 2016         Current prices      15080
# 2017         Current prices      15080
# 2018         Current prices      15080
# 2019         Current prices      15080
# 2020         Current prices      15080
# 2021         Current prices      15080
# 2022         Current prices      15080
# 2023         Current prices      15080
# 2024         Current prices      15080
# 2025         Current prices      15080

# %% [markdown]
# ## References
#
# - [Data Source](https://data-explorer.oecd.org/vis?fs[0]=Topic%2C1%7CEmployment%23JOB%23%7CBenefits%252C%20earnings%20and%20wages%23JOB_BW%23&fs[1]=Unit%20of%20measure%2C0%7CUS%20dollar%23USD%23&fs[2]=Measure%2C0%7CStatutory%20minimum%20wages%23SM_WG%23&pg=0&fc=Measure&snb=1&vw=tb&df[ds]=dsDisseminateFinalDMZ&df[id]=DSD_EARNINGS%40MW_CURP&df[ag]=OECD.ELS.SAE&df[vs]=1.0&dq=..USD.A...&pd=2010%2C&to[TIME_PERIOD]=false)
# - [Data Table](https://data-viewer.oecd.org/?chartId=c573c240-271d-434b-a7ef-03407b40e56b)
# - [API Guide](https://www.oecd.org/en/data/insights/data-explainers/2024/09/api.html)
# - [More Info](http://www.oecd.org/employment/emp/Minimum-wages.pdf)

# %% [markdown]
# This notebook is done by `La Wun Nannda`.
